# %% [markdown]
# # spaCy setup
#
# This notebook is set up to install and use spaCy for basic NLP workflow experiments.

# %%
import spacy

nlp = spacy.blank("en")
doc = nlp("spaCy makes it easy to build NLP pipelines.")

print("spaCy version:", spacy.__version__)
print("Tokens:", [token.text for token in doc])
# Out:
# spaCy version: 3.8.14
# Tokens: ['spaCy', 'makes', 'it', 'easy', 'to', 'build', 'NLP', 'pipelines', '.']
